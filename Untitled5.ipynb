# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# control display of seaborn data
pd. options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"CAF1DE"})

# %%
#dataset before cleaning
df=pd.read_csv('UceResultsBySchool2011-2016.csv')
print(df)
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
df.head(20)
# Out:
#     YEAR      DISTRICT                                   SCHOOL  \
# 0   2011         WAKISO                      GAYAZA HIGH SCHOOL
# 1   2011         MUKONO                      NAMILYANGO COLLEGE
# 2   2011         MUKONO                  MT.ST.MARY'S,NAMAGUNGA
# 3   2011         WAKISO             UGANDA MARTYRS SS,NAMUGONGO
# 4   2011  BUSHENYI MAIN                         KITABI SEMINARY
# 5   2011    MASAKA MAIN               ST.HENRY'S COLLEGE,KITOVU
# 6   2011         WAKISO                     KING'S COLLEGE,BUDO
# 7   2011        KIBAALE              NOTRE DAME ACADEMY,BUSEESA
# 8   2011        KAMPALA               ST.JOSEPH'S GIRLS,NSAMBYA
# 9   2011         WAKISO      ST.MARY'S SECONDARY SCHOOL,KITENDE
# 10  2011        MBARARA                            NTARE SCHOOL
# 11  2011         WAKISO                ST.MARY'S COLLEGE,KISUBI
# 12  2011        KALUNGU                 BUKALASA MINOR SEMINARY
# 13  2011        MBARARA                    MARYHILL HIGH SCHOOL
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
#removing white spaces
df.columns=df.columns.to_series().apply(lambda x:x.strip())
# Out:
#   File "C:\Users\laptop\AppData\Local\Temp\ipykernel_1092\1463135356.py", line 2
#     df.columns=df.columns.to_series().apply(lambdax:x.strip())
#                                                    ^
# SyntaxError: invalid syntax

# %%
#replace coulumns with 
df.columns=df.columns.str.replace(' ',' ')
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9616\774515953.py in <module>
#       1 #replace coulumns with
# ----> 2 df.columns=df.columns.str.replace(' ',' ')
#       3 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
#check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17639 entries, 0 to 17638
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                17639 non-null  int64
#  1   DISTRICT            17639 non-null  object
#  2   SCHOOL              17638 non-null  object
#  3   TOTAL CANDIDATES    17368 non-null  float64
#  4   TOTAL DIV 1         12858 non-null  float64
#  5   % DIV 1             17639 non-null  float64
#  6   TOTAL DIV 2         16880 non-null  float64
#  7   % DIV 2             17639 non-null  float64
#  8   TOTAL DIV 3         17168 non-null  float64
#  9   % DIV 3             17639 non-null  float64
#  10  TOTAL DIV 4         16888 non-null  float64
#  11  % DIV 4             17639 non-null  float64
#  12  TOTAL DIV 7         6489 non-null   float64
#  13  % DIV 7             17639 non-null  float64
#  14  TOTAL DIV 9         13454 non-null  float64
# ...

# %%
#check for duplicatesand drop them
for isduplicate in df.duplicated()
    if isduplicate:
        print('dupli')
        df.drop_duplicate(inplace=True)
        break
    else:
        pass
    print('no duplicates')
    df[df.duplicated()==True]
# Out:
#   File "C:\Users\laptop\AppData\Local\Temp\ipykernel_1092\3973332052.py", line 2
#     for isduplicate in df.duplicated()
#                                       ^
# SyntaxError: invalid syntax

# %%
#checking for null and NAN values in dataset
df.isna().any()
# Out:
# YEAR                  False
# DISTRICT              False
# SCHOOL                 True
# TOTAL CANDIDATES       True
# TOTAL DIV 1            True
# % DIV 1               False
# TOTAL DIV 2            True
# % DIV 2               False
# TOTAL DIV 3            True
# % DIV 3               False
# TOTAL DIV 4            True
# % DIV 4               False
# TOTAL DIV 7            True
# % DIV 7               False
# TOTAL DIV 9            True
# % DIV 9               False
# TOTAL X                True
# % X                   False
# FEMALE CANDIDATES     False
# FEMALE TOTAL DIV1      True
# FEMALE % DIV1          True
# FEMALE TOTAL DIV2      True
# FEMALE % DIV2          True
# FEMALE TOTAL DIV3      True
# FEMALE % DIV3          True
# FEMALE TOTAL DIV4      True
# FEMALE % DIV4          True
# FEMALE TOTAL DIV7      True
# FEMALE % DIV7          True
# FEMALE TOTAL DIV9      True
# FEMALE % DIV9          True
# FEMALE TOTAL X         True
# FEMALE % X             True
# ...

# %% [markdown]
# #check for the number of rows that are null
# null_row=df[df.isna().any(axis=1)]
# before_comparison = len(null_rows.axes[0]
# print('no of rows that are null values:')

# %%
#remove rows without school names
df.dropna(thresh=None,subset=['SCHOOL'],inplace=True)

# %%
#statics for data science
#descriptive statistics,measure central Tendency(mean,median,mode),standard
#measure dispersion(standard)
#probability
#inferential statistics(make predictions,identity,variables and hypothesis)
#modelling
#ml
#regression,classification,cluster,anomly detection
#python data correlation
#use method corr()calculates correlation coefficients between all columns in dataframe
#strong positive correlation 1 strong negative correlation
#good correlation

# %%
df = pd.DataFrame((
'x':[1,2,9,7,5]
'y':[6,7,8,9,10]
'z':[]))
